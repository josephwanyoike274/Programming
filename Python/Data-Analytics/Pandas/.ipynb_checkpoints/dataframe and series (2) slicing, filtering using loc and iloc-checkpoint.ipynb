# %%
import pandas as pd

# %%
df = pd.read_csv("survey_results_public.csv")

# %%
df_schema = pd.read_csv("survey_results_schema.csv")

# %%
pd.set_option("display.max_columns", 85)

# %%
pd.set_option("display.max_rows", 85)

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
#dictionaries in python

# %%
people = {
    "first_name" : ["joseph", "monicah", "lydia"],
    "last_name": ["wanyoike", "wambui", "mwaura"],
    "career" : ["data scientist", "accountant", "chef"]
}

# %%
people #keys are columns and values are the rows
# Out:
# {'first_name': ['joseph', 'monicah', 'lydia'],
#  'last_name': ['wanyoike', 'wambui', 'mwaura'],
#  'career': ['data scientist', 'accountant', 'chef']}

# %%
people ["career"] #displays the career key
# Out:
# ['data scientist', 'accountant', 'chef']

# %%
df_people = pd.DataFrame(people) #creates a dataframe -----NOTE BETTER on the casing of the word DataFrame

# %%
df_people
# Out:
#   first_name last_name          career
# 0     joseph  wanyoike  data scientist
# 1    monicah    wambui      accountant
# 2      lydia    mwaura            chef

# %%
df_people["career"] #displays the careee column
# Out:
# 0    data scientist
# 1        accountant
# 2              chef
# Name: career, dtype: object

# %%
type(df_people["first_name"]) #k is rows of a single column
# Out:
# pandas.core.series.Series

# %%
df_people.career #also displays the career column ------same as line 21
# Out:
# 0    data scientist
# 1        accountant
# 2              chef
# Name: career, dtype: object

# %%
df_people [['first_name', 'last_name']] #displays those 2 columns
# Out:
#   first_name last_name
# 0     joseph  wanyoike
# 1    monicah    wambui
# 2      lydia    mwaura

# %%
df_people.columns
# Out:
# Index(['first_name', 'last_name', 'career'], dtype='object')

# %%
# iloc enables us to access rows per interger location(iloc)

# %%
df_people.iloc[0]
# Out:
# first_name            joseph
# last_name           wanyoike
# career        data scientist
# Name: 0, dtype: object

# %%
df_people.iloc[[0, 1]]#displays all columns of the first and second rows
# Out:
#   first_name last_name          career
# 0     joseph  wanyoike  data scientist
# 1    monicah    wambui      accountant

# %%
df_people.iloc[[0, 1], 2]#displays 3rd (index 2)column of the rirst 2 rows
# Out:
# 0    data scientist
# 1        accountant
# Name: career, dtype: object

# %%
#loc uses labels

# %%
df_people.loc[0]#displays the first row/labeled 0
# Out:
# first_name            joseph
# last_name           wanyoike
# career        data scientist
# Name: 0, dtype: object

# %%
df_people.loc[[0, 1]] #displays the first and second rows
# Out:
#   first_name last_name          career
# 0     joseph  wanyoike  data scientist
# 1    monicah    wambui      accountant

# %%
df_people.loc[[0, 1], "career"] #displays career of the first and second rows
# Out:
# 0    data scientist
# 1        accountant
# Name: career, dtype: object

# %%
df_people.loc[[0, 1], ["career", "last_name"]] #notice the order it displays---- as we wrote on the code
# Out:
#            career last_name
# 0  data scientist  wanyoike
# 1      accountant    wambui

# %%
df.shape #rows vs colmns
# Out:
# (88883, 85)

# %%
df.columns #displays all the columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df["Hobbyist"]
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df["Hobbyist"].value_counts() #counts the responses the hobbyist question
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df.loc[0, "Hobbyist"] #displays the first response to the hobbyist question
# Out:
# 'Yes'

# %%
df.loc[[0,1,2], "Hobbyist"]#displays the first 3 responses to the hobbyist question
# Out:
# 0    Yes
# 1     No
# 2    Yes
# Name: Hobbyist, dtype: object

# %%
df.loc[0:3, "Hobbyist"] #Notice we dont put square brackets when slicing----displays the first 4 responses
# Out:
# 0    Yes
# 1     No
# 2    Yes
# 3     No
# Name: Hobbyist, dtype: object

# %%
df.loc[0:2, 'Hobbyist' : 'Employment'] #we are slicing the first 3 rows and then columns from hobbyist to employment
# Out:
#   Hobbyist              OpenSourcer  \
# 0      Yes                    Never
# 1       No  Less than once per year
# 2      Yes                    Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
#
#                                Employment
# 0  Not employed, and not looking for work
# 1      Not employed, but looking for work
# 2                      Employed full-time
